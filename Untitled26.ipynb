# %%
# 패키지 설치
# !pip install keras-tuner
# !apt-get install -y fonts-nanum
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.32.3)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.8.30)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.9 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,662 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 119634 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# 라이브러리 임포트 및 설정
import os
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Input, Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from google.colab import drive
from tensorflow.keras.applications import VGG16  # VGG16로 변경
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import keras_tuner as kt
import unicodedata
import matplotlib.font_manager as fm
import matplotlib
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.utils import Sequence

# %%
# 한글 폰트 설정

# 1. 폰트 경로 설정
font_dirs = ['/usr/share/fonts/truetype/nanum/']
font_files = fm.findSystemFonts(fontpaths=font_dirs)

# 2. 폰트를 폰트 매니저에 추가
for font_file in font_files:
    fm.fontManager.addfont(font_file)

# 3. 폰트 설정
matplotlib.rcParams['font.family'] = 'NanumGothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
# Google Drive 마운트
drive.mount('/content/drive')

# 데이터 경로 설정
base_dir = '/content/drive/MyDrive/Colab Notebooks/testset'
image_dir = os.path.join(base_dir, 'TS_Color_위해물품')
label_dir = os.path.join(base_dir, 'TL_위해물품')

# 밀도 정보 및 색상 정보 정의
density_info = {
    "metal_density_high": 8.0,    # 금속의 높은 밀도 기준 값 (예시)
    "metal_density_low": 5.0,     # 금속의 낮은 밀도 기준 값 (예시)
    "plastic_density_high": 1.5,  # 플라스틱의 높은 밀도 기준 값 (예시)
    "plastic_density_low": 0.8,   # 플라스틱의 낮은 밀도 기준 값 (예시)
    "metal_high_density_color": "#00008B",    # 짙은 파란색 (DarkBlue)
    "metal_low_density_color": "#90EE90",     # 연두색 (LightGreen)
    "plastic_high_density_color": "#FF8C00",  # 짙은 주황색 (DarkOrange)
    "plastic_low_density_color": "#FFA07A",   # 옅은 주황색 (LightSalmon)
}

# JSON 파일의 메타데이터 업데이트
directory_path = label_dir

# 디렉토리 내 모든 JSON 파일을 순회
for filename in os.listdir(directory_path):
    if filename.endswith('.json'):
        file_path = os.path.join(directory_path, filename)

        # JSON 파일 읽기
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)

        # 메타데이터 업데이트
        if "meta" in data:
            for item in data["meta"]:
                if "material_inside" in item:
                    # 밀도값 추가 (실제 값으로 설정)
                    if item["material_inside"] == "Metal":
                        # 아이템의 실제 금속 밀도 값을 설정해야 합니다.
                        # 예시로 임의의 값을 사용합니다.
                        item["density"] = 7.5  # 실제 밀도 값으로 대체
                        # 밀도에 따른 색상 결정
                        if item["density"] >= density_info["metal_density_high"]:
                            item.update({
                                "color": density_info["metal_high_density_color"]
                            })
                        else:
                            item.update({
                                "color": density_info["metal_low_density_color"]
                            })
                    elif item["material_inside"] == "Plastic":
                        # 아이템의 실제 플라스틱 밀도 값을 설정해야 합니다.
                        # 예시로 임의의 값을 사용합니다.
                        item["density"] = 1.2  # 실제 밀도 값으로 대체
                        # 밀도에 따른 색상 결정
                        if item["density"] >= density_info["plastic_density_high"]:
                            item.update({
                                "color": density_info["plastic_high_density_color"]
                            })
                        else:
                            item.update({
                                "color": density_info["plastic_low_density_color"]
                            })

        # 변경된 데이터 저장
        with open(file_path, 'w', encoding='utf-8') as file:
            json.dump(data, file, ensure_ascii=False, indent=4)

print("메타데이터가 모든 파일에 업데이트되었습니다.")
# Out:
# Mounted at /content/drive
# 메타데이터가 모든 파일에 업데이트되었습니다.

# %%
# 이미지에서 밀도값 추정 함수 정의
def estimate_density_from_image(image):
    # 이미지의 평균 밝기 계산 (예시)
    grayscale_image = tf.image.rgb_to_grayscale(image)
    mean_intensity = tf.reduce_mean(grayscale_image)
    # 밀도값은 밝기에 반비례한다고 가정 (예시)
    # 밝기가 높을수록 밀도가 낮은 물질로 간주
    estimated_density = 1.0 / (mean_intensity + 1e-5)  # 0으로 나누기 방지
    return estimated_density.numpy()

# 이미지 경로와 추정된 밀도값을 저장할 리스트 초기화
image_paths = []
labels = []
estimated_densities = []

# 클래스 레이블 가져오기 및 Unicode 정규화
class_labels = sorted(os.listdir(image_dir))
class_labels = [unicodedata.normalize('NFC', label) for label in class_labels]
num_classes = len(class_labels)
print(f"클래스 레이블: {class_labels}")

# 이미지와 레이블 수집 및 밀도값 추정
for class_label in class_labels:
    class_dir = os.path.join(image_dir, class_label)
    if os.path.isdir(class_dir):
        for img_name in os.listdir(class_dir):
            if img_name.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
                img_path = os.path.join(class_dir, img_name)
                image_paths.append(img_path)
                labels.append(unicodedata.normalize('NFC', class_label))
                # 이미지 로드 및 전처리
                image = tf.io.read_file(img_path)
                image = tf.image.decode_image(image, channels=3)
                image = tf.image.resize(image, [224, 224])
                image = image / 255.0  # 정규화
                # 밀도값 추정
                density = estimate_density_from_image(image)
                estimated_densities.append(density)

# 데이터를 데이터프레임으로 구성
data_df = pd.DataFrame({'filename': image_paths, 'label': labels, 'density': estimated_densities})

# 밀도값 정규화 (모델 입력에 사용하기 위해)
scaler = MinMaxScaler()
data_df['density_normalized'] = scaler.fit_transform(data_df[['density']])

# 레이블 인코딩 (클래스 가중치 계산을 위해 정수 인코딩)
label_encoder = LabelEncoder()
data_df['label_encoded'] = label_encoder.fit_transform(data_df['label'])
# Out:
# 클래스 레이블: ['TS_Color_위해물품_Bullet_총알', 'TS_Color_위해물품_Card knife_카드칼(접은 형태)(167)', 'TS_Color_위해물품_Electroshock weapon_전자충격기', 'TS_Color_위해물품_Grenade_수류탄', 'TS_Color_위해물품_Knife blade_칼날(030)', 'TS_Color_위해물품_Knife-D_맥가이버 칼(접은 형태)(029)', 'TS_Color_위해물품_Knife-E_펜칼', 'TS_Color_위해물품_Pistol_모형 권총(금속 재질)', 'TS_Color_위해물품_Pistol_모형 권총(플라스틱 재질)', 'TS_Color_위해물품_Rifle_모형 소총(플라스틱 재질)', 'TS_Color_위해물품_Scissors-A_문구용 가위(접은 형태)(037)']

# %%
# 데이터세트 분할 (70% 훈련, 20% 검증, 10% 테스트)
train_df, temp_df = train_test_split(data_df, test_size=0.3, random_state=42, stratify=data_df['label'])
val_df, test_df = train_test_split(temp_df, test_size=0.33, random_state=42, stratify=temp_df['label'])  # 0.33 * 0.3 ≈ 0.1

# 클래스 가중치 계산
classes = np.unique(train_df['label_encoded'])
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=train_df['label_encoded']
)

# 최대 가중치 제한 적용
max_weight = 5.0  # 최대 가중치 제한
class_weights = np.clip(class_weights, 0, max_weight)

# 클래스 가중치 딕셔너리 생성
class_weight_dict = dict(zip(classes, class_weights))

print("클래스 가중치:")
print(class_weight_dict)
# Out:
# 클래스 가중치:
# {0: 1.233663650725262, 1: 1.5192783869826672, 2: 4.6482683982683985, 3: 3.754370629370629, 4: 0.598856664807585, 5: 0.378898151823916, 6: 2.0126522961574507, 7: 1.543298598634567, 8: 0.7105633220282902, 9: 5.0, 10: 0.4850367024280068}

# %%
# 배치 크기 설정
batch_size = 32

# 데이터 제너레이터 설정 (수정됨)
datagen_train = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen_val_test = ImageDataGenerator(rescale=1./255)

# 커스텀 제너레이터 클래스 정의 (추가됨)
class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, is_training, datagen):
        self.df = df.reset_index(drop=True)
        self.batch_size = batch_size
        self.is_training = is_training
        self.datagen = datagen
        self.indices = np.arange(len(self.df))
        self.on_epoch_end()
    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))
    def __getitem__(self, idx):
        batch_indices = self.indices[idx * self.batch_size : (idx + 1) * self.batch_size]
        batch_df = self.df.iloc[batch_indices]
        batch_images = []
        for filename in batch_df['filename']:
            img = tf.keras.preprocessing.image.load_img(filename, target_size=(224, 224))
            img = tf.keras.preprocessing.image.img_to_array(img)
            batch_images.append(img)
        batch_images = np.array(batch_images)
        if self.is_training:
            batch_images = self.datagen.flow(batch_images, batch_size=len(batch_images), shuffle=False).next()
        else:
            batch_images = batch_images / 255.0
        batch_density = batch_df['density_normalized'].values
        batch_labels = batch_df['label']
        batch_labels_encoded = label_encoder.transform(batch_labels)
        batch_labels_onehot = tf.keras.utils.to_categorical(batch_labels_encoded, num_classes=num_classes)
        return [batch_images, batch_density], batch_labels_onehot
    def on_epoch_end(self):
        if self.is_training:
            np.random.shuffle(self.indices)

# %%
# 제너레이터 생성
train_generator = CustomDataGenerator(train_df, batch_size, is_training=True, datagen=datagen_train)
validation_generator = CustomDataGenerator(val_df, batch_size, is_training=False, datagen=datagen_val_test)
test_generator = CustomDataGenerator(test_df, batch_size, is_training=False, datagen=datagen_val_test)

steps_per_epoch = len(train_generator)
validation_steps = len(validation_generator)
test_steps = len(test_generator)

# %%
# 클래스 인덱스와 클래스명 매핑
class_indices = {v: k for k, v in enumerate(label_encoder.classes_)}
inv_class_indices = {v: k for k, v in class_indices.items()}

# 클래스 레이블 매핑 생성 (한글 클래스명 간소화)
class_label_mapping = {
    'TS_Color_위해물품_Bullet_총알': '총알',
    'TS_Color_위해물품_Card knife_카드칼(접은 형태)(167)': '카드칼',
    'TS_Color_위해물품_Electroshock weapon_전자충격기': '전자충격기',
    'TS_Color_위해물품_Grenade_수류탄': '수류탄',
    'TS_Color_위해물품_Knife blade_칼날(030)': '칼날',
    'TS_Color_위해물품_Knife-D_맥가이버 칼(접은 형태)(029)': '맥가이버 칼',
    'TS_Color_위해물품_Knife-E_펜칼': '펜칼',
    'TS_Color_위해물품_Pistol_모형 권총(금속 재질)': '금속 권총',
    'TS_Color_위해물품_Pistol_모형 권총(플라스틱 재질)': '플라스틱 권총',
    'TS_Color_위해물품_Rifle_모형 소총(플라스틱 재질)': '플라스틱 소총',
    'TS_Color_위해물품_Scissors-A_문구용 가위(접은 형태)(037)': '가위',
}

# 클래스 레이블 매핑의 키를 NFC로 정규화
class_label_mapping_normalized = {unicodedata.normalize('NFC', k): v for k, v in class_label_mapping.items()}

# %%
# 모델 정의 및 컴파일
def build_model(hp):
    # 이미지 입력
    image_input = Input(shape=(224, 224, 3), name='image_input')
    # 밀도값 입력
    density_input = Input(shape=(1,), name='density_input')

    # 베이스 모델 (VGG16)
    base_model = VGG16(input_tensor=image_input, include_top=False, weights='imagenet')
    base_model.trainable = True  # 모든 레이어를 학습 가능하게 설정

    # 특정 레이어까지 동결 (VGG16의 경우)
    for layer in base_model.layers[:10]:
        layer.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)

    # 밀도값과 합치기
    x = Concatenate()([x, density_input])

    x = Dense(
        units=hp.Int('units_dense1', min_value=256, max_value=1024, step=256),
        activation='relu'
    )(x)
    x = Dropout(hp.Float('dropout_rate1', min_value=0.3, max_value=0.7, step=0.1))(x)
    x = Dense(
        units=hp.Int('units_dense2', min_value=128, max_value=512, step=128),
        activation='relu'
    )(x)
    x = Dropout(hp.Float('dropout_rate2', min_value=0.3, max_value=0.7, step=0.1))(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=[image_input, density_input], outputs=outputs)

    optimizer = tf.keras.optimizers.Adam(
        learning_rate=hp.Float('learning_rate', min_value=1e-5, max_value=1e-3, sampling='log')
    )

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# 튜너 설정
tuner = kt.Hyperband(
    build_model,
    objective='val_accuracy',
    max_epochs=10,
    factor=3,
    directory='tuner_dir',
    project_name='vgg16_tuning_with_density'  # 프로젝트 이름 변경
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
# 콜백 정의
stop_early = EarlyStopping(monitor='val_loss', patience=2)

# %%
# 튜닝 수행
tuner.search(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    epochs=10,
    callbacks=[stop_early]
)
# Out:
# Trial 30 Complete [01h 24m 14s]
# val_accuracy: 0.4586374759674072
#
# Best val_accuracy So Far: 0.5729926824569702
# Total elapsed time: 16h 24m 40s

# %%
# 최적의 하이퍼파라미터로 모델 빌드
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
최적의 하이퍼파라미터:
- units_dense1: {best_hps.get('units_dense1')}
- dropout_rate1: {best_hps.get('dropout_rate1')}
- units_dense2: {best_hps.get('units_dense2')}
- dropout_rate2: {best_hps.get('dropout_rate2')}
- learning_rate: {best_hps.get('learning_rate')}
""")

# 최적의 하이퍼파라미터로 모델 생성
model = tuner.hypermodel.build(best_hps)
# Out:
# 최적의 하이퍼파라미터:
# - units_dense1: 1024
# - dropout_rate1: 0.3
# - units_dense2: 384
# - dropout_rate2: 0.4
# - learning_rate: 1.64395039994333e-05

# %%
# 콜백 설정
checkpoint_cb = ModelCheckpoint("/content/drive/MyDrive/Colab Notebooks/checkpoints/model_vgg16_with_density.h5", save_best_only=True)
reduce_lr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping_cb = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# 모델 훈련 (클래스 가중치 적용)
history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=validation_steps,
    epochs=50,
    callbacks=[checkpoint_cb, reduce_lr_cb, early_stopping_cb],
    class_weight=class_weight_dict  # 클래스 가중치 적용
)
# Out:
# Epoch 1/50
# 269/269 [==============================] - ETA: 0s - loss: 2.3692 - accuracy: 0.0955
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 517s 2s/step - loss: 2.3692 - accuracy: 0.0955 - val_loss: 2.3914 - val_accuracy: 0.0673 - lr: 1.6440e-05
# Epoch 2/50
# 269/269 [==============================] - ETA: 0s - loss: 2.3016 - accuracy: 0.1149
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 507s 2s/step - loss: 2.3016 - accuracy: 0.1149 - val_loss: 2.3207 - val_accuracy: 0.1277 - lr: 1.6440e-05
# Epoch 3/50
# 269/269 [==============================] - ETA: 0s - loss: 2.2252 - accuracy: 0.1321
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 507s 2s/step - loss: 2.2252 - accuracy: 0.1321 - val_loss: 2.2151 - val_accuracy: 0.2036 - lr: 1.6440e-05
# Epoch 4/50
# 269/269 [==============================] - ETA: 0s - loss: 2.0935 - accuracy: 0.1552
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 506s 2s/step - loss: 2.0935 - accuracy: 0.1552 - val_loss: 2.1942 - val_accuracy: 0.2125 - lr: 1.6440e-05
# Epoch 5/50
# 269/269 [==============================] - ETA: 0s - loss: 1.9313 - accuracy: 0.2087
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 507s 2s/step - loss: 1.9313 - accuracy: 0.2087 - val_loss: 2.1671 - val_accuracy: 0.2656 - lr: 1.6440e-05
# Epoch 6/50
# 269/269 [==============================] - 503s 2s/step - loss: 1.8230 - accuracy: 0.2497 - val_loss: 2.2039 - val_accuracy: 0.2486 - lr: 1.6440e-05
# Epoch 7/50
# 269/269 [==============================] - ETA: 0s - loss: 1.6997 - accuracy: 0.2955
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 507s 2s/step - loss: 1.6997 - accuracy: 0.2955 - val_loss: 2.0479 - val_accuracy: 0.2713 - lr: 1.6440e-05
# Epoch 8/50
# 269/269 [==============================] - ETA: 0s - loss: 1.6073 - accuracy: 0.3178
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 507s 2s/step - loss: 1.6073 - accuracy: 0.3178 - val_loss: 1.9404 - val_accuracy: 0.3009 - lr: 1.6440e-05
# Epoch 9/50
# 269/269 [==============================] - ETA: 0s - loss: 1.5014 - accuracy: 0.3554
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 506s 2s/step - loss: 1.5014 - accuracy: 0.3554 - val_loss: 1.6201 - val_accuracy: 0.3982 - lr: 1.6440e-05
# Epoch 10/50
# 269/269 [==============================] - 505s 2s/step - loss: 1.4181 - accuracy: 0.3836 - val_loss: 1.6872 - val_accuracy: 0.3836 - lr: 1.6440e-05
# Epoch 11/50
# 269/269 [==============================] - 504s 2s/step - loss: 1.3601 - accuracy: 0.4049 - val_loss: 1.7853 - val_accuracy: 0.3865 - lr: 1.6440e-05
# Epoch 12/50
# 269/269 [==============================] - ETA: 0s - loss: 1.2880 - accuracy: 0.4308
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 505s 2s/step - loss: 1.2880 - accuracy: 0.4308 - val_loss: 1.5517 - val_accuracy: 0.4550 - lr: 1.6440e-05
# Epoch 13/50
# 269/269 [==============================] - ETA: 0s - loss: 1.2310 - accuracy: 0.4595
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 506s 2s/step - loss: 1.2310 - accuracy: 0.4595 - val_loss: 1.3548 - val_accuracy: 0.5004 - lr: 1.6440e-05
# Epoch 14/50
# 269/269 [==============================] - ETA: 0s - loss: 1.1731 - accuracy: 0.4785
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 507s 2s/step - loss: 1.1731 - accuracy: 0.4785 - val_loss: 1.2994 - val_accuracy: 0.5041 - lr: 1.6440e-05
# Epoch 15/50
# 269/269 [==============================] - 504s 2s/step - loss: 1.1091 - accuracy: 0.4952 - val_loss: 1.4884 - val_accuracy: 0.4830 - lr: 1.6440e-05
# Epoch 16/50
# 269/269 [==============================] - ETA: 0s - loss: 1.0652 - accuracy: 0.5122
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 504s 2s/step - loss: 1.0652 - accuracy: 0.5122 - val_loss: 1.2629 - val_accuracy: 0.5442 - lr: 1.6440e-05
# Epoch 17/50
# 269/269 [==============================] - ETA: 0s - loss: 1.0429 - accuracy: 0.5189
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 506s 2s/step - loss: 1.0429 - accuracy: 0.5189 - val_loss: 1.2069 - val_accuracy: 0.5641 - lr: 1.6440e-05
# Epoch 18/50
# 269/269 [==============================] - 504s 2s/step - loss: 1.0077 - accuracy: 0.5354 - val_loss: 1.3183 - val_accuracy: 0.5353 - lr: 1.6440e-05
# Epoch 19/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.9684 - accuracy: 0.5515 - val_loss: 1.3877 - val_accuracy: 0.5373 - lr: 1.6440e-05
# Epoch 20/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.9439 - accuracy: 0.5654 - val_loss: 1.3311 - val_accuracy: 0.5337 - lr: 1.6440e-05
# Epoch 21/50
# 269/269 [==============================] - ETA: 0s - loss: 0.9080 - accuracy: 0.5751
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 504s 2s/step - loss: 0.9080 - accuracy: 0.5751 - val_loss: 1.2065 - val_accuracy: 0.5876 - lr: 1.6440e-05
# Epoch 22/50
# 269/269 [==============================] - 505s 2s/step - loss: 0.8750 - accuracy: 0.5913 - val_loss: 1.3077 - val_accuracy: 0.5560 - lr: 1.6440e-05
# Epoch 23/50
# 269/269 [==============================] - ETA: 0s - loss: 0.8412 - accuracy: 0.6085
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 504s 2s/step - loss: 0.8412 - accuracy: 0.6085 - val_loss: 1.2023 - val_accuracy: 0.5872 - lr: 1.6440e-05
# Epoch 24/50
# 269/269 [==============================] - ETA: 0s - loss: 0.8034 - accuracy: 0.6201
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 506s 2s/step - loss: 0.8034 - accuracy: 0.6201 - val_loss: 1.0641 - val_accuracy: 0.6233 - lr: 1.6440e-05
# Epoch 25/50
# 269/269 [==============================] - 505s 2s/step - loss: 0.7683 - accuracy: 0.6336 - val_loss: 1.1678 - val_accuracy: 0.5994 - lr: 1.6440e-05
# Epoch 26/50
# 269/269 [==============================] - ETA: 0s - loss: 0.7664 - accuracy: 0.6378
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 506s 2s/step - loss: 0.7664 - accuracy: 0.6378 - val_loss: 1.0508 - val_accuracy: 0.6346 - lr: 1.6440e-05
# Epoch 27/50
# 269/269 [==============================] - 504s 2s/step - loss: 0.7014 - accuracy: 0.6651 - val_loss: 1.1710 - val_accuracy: 0.6160 - lr: 1.6440e-05
# Epoch 28/50
# 269/269 [==============================] - ETA: 0s - loss: 0.7026 - accuracy: 0.6660
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 507s 2s/step - loss: 0.7026 - accuracy: 0.6660 - val_loss: 1.0266 - val_accuracy: 0.6553 - lr: 1.6440e-05
# Epoch 29/50
# 269/269 [==============================] - 504s 2s/step - loss: 0.6689 - accuracy: 0.6764 - val_loss: 1.0550 - val_accuracy: 0.6577 - lr: 1.6440e-05
# Epoch 30/50
# 269/269 [==============================] - 504s 2s/step - loss: 0.6511 - accuracy: 0.6871 - val_loss: 1.0395 - val_accuracy: 0.6472 - lr: 1.6440e-05
# Epoch 31/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.6554 - accuracy: 0.6895 - val_loss: 1.0771 - val_accuracy: 0.6379 - lr: 1.6440e-05
# Epoch 32/50
# 269/269 [==============================] - ETA: 0s - loss: 0.6055 - accuracy: 0.7005
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 504s 2s/step - loss: 0.6055 - accuracy: 0.7005 - val_loss: 0.9488 - val_accuracy: 0.6764 - lr: 1.6440e-05
# Epoch 33/50
# 269/269 [==============================] - 504s 2s/step - loss: 0.5923 - accuracy: 0.7129 - val_loss: 1.0312 - val_accuracy: 0.6598 - lr: 1.6440e-05
# Epoch 34/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.5815 - accuracy: 0.7198 - val_loss: 1.0043 - val_accuracy: 0.6792 - lr: 1.6440e-05
# Epoch 35/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.5563 - accuracy: 0.7288 - val_loss: 1.0947 - val_accuracy: 0.6419 - lr: 1.6440e-05
# Epoch 36/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.5742 - accuracy: 0.7292 - val_loss: 0.9722 - val_accuracy: 0.6813 - lr: 1.6440e-05
# Epoch 37/50
# 269/269 [==============================] - ETA: 0s - loss: 0.5449 - accuracy: 0.7346
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 506s 2s/step - loss: 0.5449 - accuracy: 0.7346 - val_loss: 0.8653 - val_accuracy: 0.7182 - lr: 1.6440e-05
# Epoch 38/50
# 269/269 [==============================] - 505s 2s/step - loss: 0.5260 - accuracy: 0.7403 - val_loss: 0.8686 - val_accuracy: 0.7202 - lr: 1.6440e-05
# Epoch 39/50
# 269/269 [==============================] - 502s 2s/step - loss: 0.5349 - accuracy: 0.7492 - val_loss: 0.8741 - val_accuracy: 0.7182 - lr: 1.6440e-05
# Epoch 40/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.4911 - accuracy: 0.7587 - val_loss: 0.9918 - val_accuracy: 0.6886 - lr: 1.6440e-05
# Epoch 41/50
# 269/269 [==============================] - 502s 2s/step - loss: 0.4617 - accuracy: 0.7658 - val_loss: 1.0657 - val_accuracy: 0.7019 - lr: 1.6440e-05
# Epoch 42/50
# 269/269 [==============================] - ETA: 0s - loss: 0.4736 - accuracy: 0.7647
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 505s 2s/step - loss: 0.4736 - accuracy: 0.7647 - val_loss: 0.8271 - val_accuracy: 0.7393 - lr: 1.6440e-05
# Epoch 43/50
# 269/269 [==============================] - 505s 2s/step - loss: 0.4542 - accuracy: 0.7756 - val_loss: 1.1939 - val_accuracy: 0.6671 - lr: 1.6440e-05
# Epoch 44/50
# 269/269 [==============================] - 505s 2s/step - loss: 0.4616 - accuracy: 0.7796 - val_loss: 0.9290 - val_accuracy: 0.7161 - lr: 1.6440e-05
# Epoch 45/50
# 269/269 [==============================] - ETA: 0s - loss: 0.4227 - accuracy: 0.7887
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 269/269 [==============================] - 506s 2s/step - loss: 0.4227 - accuracy: 0.7887 - val_loss: 0.7895 - val_accuracy: 0.7547 - lr: 1.6440e-05
# Epoch 46/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.4277 - accuracy: 0.7979 - val_loss: 1.0280 - val_accuracy: 0.6894 - lr: 1.6440e-05
# Epoch 47/50
# 269/269 [==============================] - 503s 2s/step - loss: 0.4249 - accuracy: 0.7983 - val_loss: 0.9225 - val_accuracy: 0.7259 - lr: 1.6440e-05
# Epoch 48/50
# 269/269 [==============================] - 501s 2s/step - loss: 0.3906 - accuracy: 0.8009 - val_loss: 0.9659 - val_accuracy: 0.7307 - lr: 1.6440e-05
# Epoch 49/50
# 269/269 [==============================] - 501s 2s/step - loss: 0.3945 - accuracy: 0.8023 - val_loss: 0.9138 - val_accuracy: 0.7352 - lr: 1.6440e-05
# Epoch 50/50
# 269/269 [==============================] - 502s 2s/step - loss: 0.4053 - accuracy: 0.8014 - val_loss: 0.8728 - val_accuracy: 0.7332 - lr: 1.6440e-05

# %%
# 학습 곡선 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='훈련 정확도')
plt.plot(history.history['val_accuracy'], label='검증 정확도')
plt.title('훈련 및 검증 정확도')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='훈련 손실')
plt.plot(history.history['val_loss'], label='검증 손실')
plt.title('훈련 및 검증 손실')
plt.legend()

plt.show()

# %%
# 모델 평가
test_loss, test_acc = model.evaluate(test_generator, steps=test_steps)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_acc}")
# Out:
# 38/38 [==============================] - 37s 963ms/step - loss: 0.9366 - accuracy: 0.7245
# Test Loss: 0.9366450309753418
# Test Accuracy: 0.7245065569877625

# %%
# 예측 수행
y_pred_probs = model.predict(test_generator, steps=test_steps)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = []
for i in range(test_steps):
    (_, _), batch_y = test_generator[i]
    y_true_classes.extend(np.argmax(batch_y, axis=1))
y_true_classes = np.array(y_true_classes)
# Out:
# 38/38 [==============================] - 37s 962ms/step

# %%
# 클래스 인덱스와 클래스 레이블 매핑
inv_class_indices_mapped = {k: class_label_mapping_normalized.get(unicodedata.normalize('NFC', inv_class_indices[k]), inv_class_indices[k]) for k in inv_class_indices}

# %%
# Classification Report 출력
target_names = [inv_class_indices_mapped[i] for i in range(num_classes)]
report = classification_report(
    y_true_classes,
    y_pred_classes,
    target_names=target_names,
    digits=4
)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           총알     0.4293    0.8778    0.5766        90
#          카드칼     0.6154    0.7671    0.6829        73
#        전자충격기     0.9583    0.9583    0.9583        24
#          수류탄     0.8636    0.6333    0.7308        30
#           칼날     0.6685    0.6685    0.6685       184
#       맥가이버 칼     0.9158    0.6357    0.7505       291
#           펜칼     0.5797    0.7273    0.6452        55
#        금속 권총     0.8734    0.9583    0.9139        72
#      플라스틱 권총     0.6615    0.8323    0.7371       155
#      플라스틱 소총     0.8462    0.7857    0.8148        14
#           가위     0.9608    0.6447    0.7717       228
#
#     accuracy                         0.7245      1216
#    macro avg     0.7611    0.7717    0.7500      1216
# weighted avg     0.7814    0.7245    0.7327      1216

# %%
# 혼동 행렬 계산 및 시각화
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
plt.figure(figsize=(12, 12))
disp.plot(cmap=plt.cm.Blues)
plt.xticks(rotation=90)
plt.show()

# %%
# ROC 곡선 및 AUC 값 계산
from sklearn.preprocessing import label_binarize

n_classes = num_classes
y_true_bin = label_binarize(y_true_classes, classes=range(n_classes))
y_pred_probs = y_pred_probs[:len(y_true_bin)]  # 배열 길이 맞추기 (필요한 경우)

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ROC 곡선 시각화
plt.figure(figsize=(10, 8))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'{target_names[i]} (AUC = {roc_auc[i]:0.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.title('다중 클래스에 대한 ROC 곡선')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()

# %%
# 맞춘 이미지와 틀린 이미지 시각화
# 테스트 데이터에서 이미지와 레이블 추출
x_test = []
y_test_classes = []

# 테스트 제너레이터를 순회하여 이미지와 레이블 수집
for i in range(test_steps):
    (batch_x, _), batch_y = test_generator[i]
    x_test.extend(batch_x)
    y_test_classes.extend(np.argmax(batch_y, axis=1))

# NumPy 배열로 변환
x_test = np.array(x_test)
y_test_classes = np.array(y_test_classes)

# 맞춘 샘플과 틀린 샘플의 인덱스 찾기
correct_indices = np.nonzero(y_pred_classes == y_true_classes)[0]
incorrect_indices = np.nonzero(y_pred_classes != y_true_classes)[0]

# 클래스 인덱스를 클래스명으로 변환
predicted_class_names = [inv_class_indices_mapped[i] for i in y_pred_classes]
true_class_names = [inv_class_indices_mapped[i] for i in y_true_classes]

# %%
# 맞춘 이미지 시각화
plt.figure(figsize=(10, 10))
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3, 3, i + 1)
    plt.imshow(x_test[correct].astype('uint8'))
    plt.title(f"예측: {predicted_class_names[correct]}\n실제: {true_class_names[correct]}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# 틀린 이미지 시각화
plt.figure(figsize=(10, 10))
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3, 3, i + 1)
    plt.imshow(x_test[incorrect].astype('uint8'))
    plt.title(f"예측: {predicted_class_names[incorrect]}\n실제: {true_class_names[incorrect]}")
    plt.axis('off')
plt.tight_layout()
plt.show()
